# %%
name =("Harry")

# %%
name
# Out:
# 'Harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.endswith("as")
# Out:
# False

# %%
name.endswith("ry")
# Out:
# True

# %%
name.lower()
# Out:
# 'harry'

# %%
name.count("r")
# Out:
# 2

# %%
s = "paraspilankar"

# %%
s[0:5]
# Out:
# 'paras'
