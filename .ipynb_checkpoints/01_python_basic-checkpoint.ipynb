# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Paras"

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(float(a))
# Out:
# 5.0
