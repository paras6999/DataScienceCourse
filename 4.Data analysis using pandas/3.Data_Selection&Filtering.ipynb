# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df[['Actor', 'IMDb']]
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df.loc[1]
# Out:
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df.iloc[7, 1]
# Out:
# 'War'

# %%
df.loc[1:5, ['Actor', 'IMDb', 'Film', 'Year']]
# Out:
#                 Actor  IMDb             Film  Year
# 1         Salman Khan   6.0  Tiger Zinda Hai  2017
# 2          Aamir Khan   8.4           Dangal  2016
# 3       Ranbir Kapoor   5.6       Brahmastra  2022
# 4       Ranveer Singh   7.0        Padmaavat  2018
# 5  Ayushmann Khurrana   8.3        Andhadhun  2018

# %%
df.at[0,'Actor']
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0, 0]
# Out:
# 'Shah Rukh Khan'

# %%
df[df['IMDb']>7]
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 2           Aamir Khan                    Dangal  2016      Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 5                    111   8.3
# 6                    180   7.5
# 11                   342   8.2

# %%
df[(df['IMDb']>6) | (df['Year']>2018)]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# ...

# %%
df.query("Year > 2018")
# Out:
#              Actor                      Film  Year          Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023         Action
# 3    Ranbir Kapoor                Brahmastra  2022        Fantasy
# 7   Hrithik Roshan                       War  2019         Action
# 8     Akshay Kumar                Good Newwz  2019         Comedy
# 9    Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 11                   342   8.2
